# %%
import json
import pandas as pd

# Charger le dernier fichier
filepath = "../data/BTCUSDT_20260217_120546.json"

with open(filepath, "r") as f:
    data = json.load(f)

df = pd.DataFrame(data, columns=[
    "open_time","open","high","low","close","volume",
    "close_time","quote_asset_volume","nb_trades",
    "taker_buy_base","taker_buy_quote","ignore"
])

df["open_time"] = pd.to_datetime(df["open_time"], unit="ms")
df[["open","high","low","close","volume"]] = df[["open","high","low","close","volume"]].astype(float)

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 7
#       4 # Charger le dernier fichier
#       5 filepath = "../data/BTCUSDT_20260217_120546.json"
# ----> 7 with open(filepath, "r") as f:
#       8     data = json.load(f)
#      10 df = pd.DataFrame(data, columns=[
#      11     "open_time","open","high","low","close","volume",
#      12     "close_time","quote_asset_volume","nb_trades",
#      13     "taker_buy_base","taker_buy_quote","ignore"
#      14 ])
#
# File /opt/anaconda3/lib/python3.13/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
# ...

# %%
filepath = "../data/BTCUSDT_20260217_120546.json"

# %%
import os
os.getcwd()
# Out:
# '/Users/jihanebrzg/Desktop/Project_OPA/anaconda_projects/97a65013-4c26-4043-b858-0586ebe81197'

# %%
import os

files = os.listdir("data")
latest_file = sorted(files)[-1]

filepath = f"data/{latest_file}"
print("Fichier chargé :", filepath)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 import os
# ----> 3 files = os.listdir("data")
#       4 latest_file = sorted(files)[-1]
#       6 filepath = f"data/{latest_file}"
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data'

# %%
import os
os.getcwd()
# Out:
# '/Users/jihanebrzg/Desktop/Project_OPA/anaconda_projects/97a65013-4c26-4043-b858-0586ebe81197'
